# %% [markdown]
# ### MLOps Overview
# In the previous notebook we've created a small ML Pipeline but it may have some troubles:
# - How to keep track of metrics?
# - How to store different models?
# - How to organize different steps into ML Pipeline?

# %% [markdown]
# ### Metrics Storing
# A good practice to keep track of all metrics - log them. For this purpose an `experiment tracker` can be used
# ![image.png](attachment:ef6ddeb9-cf16-421c-93a1-626801ae5638.png)

# %% [markdown]
# ### Models Storing
# Models stroing allows to answer the following questions:
# - What the model it was?
# - What performance it had?
# - How good a model is in comparison with another one?
# ![image.png](attachment:8e1c39db-2749-4fc8-aedc-b943b4c6d799.png)

# %% [markdown]
# ### ML Pipeline
# All elements in a Pipeline **are ordered** (it's a workflow)
#
# **ML Pipeline Output - a model**
#
# ![image.png](attachment:6c305c37-1c5e-4375-9882-37fe346389ee.png)

# %% [markdown]
# ### Model Deploying and Monitoring
#
# Model can be deployed on a server and serve there. However, it should be monitored (keep track of metrics)
#
# The highest automation level for ML Services is depicted below
#
# ![image.png](attachment:76bd319a-3a0e-4ca7-93a6-7aeb395c3681.png)

# %% [markdown]
# ### MLOps Maturity Model
# https://docs.microsoft.com/en-us/azure/architecture/example-scenario/mlops/mlops-maturity-model
# ![image.png](attachment:1a5be5e3-e8d5-4819-ac75-357d050e66a9.png)
# ![image.png](attachment:6f8e81ab-d68b-4062-8616-c632f061999f.png)
# ![image.png](attachment:cd8d8e94-4090-4e3c-acf9-7f15c33ce99a.png)
# ![image.png](attachment:86d45649-a262-4d61-bdd1-9055a53e89ff.png)

# %% [markdown]
# It's not always required to go to level 3-4. For most of the model level 2 is good enough!
