# %% [markdown]
# ### Duration Trip Prediction

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error

warnings.filterwarnings('ignore')

# %%
data = pd.read_parquet('../data/green_tripdata_2021-01.parquet')
data
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0             5.50   0.50      0.5        0.00          0.00      None
# 1            10.00   0.50      0.5        2.81          0.00      None
# 2             6.00   0.50      0.5        1.00          0.00      None
# 3             8.00   0.50      0.5        0.00          0.00      None
# 4           -52.00   0.00     -0.5        0.00          0.00      None
# ...            ...    ...      ...         ...           ...       ...
# 76513        56.23   2.75      0.0        0.00          6.12      None
# 76514        46.66   0.00      0.0       12.20          6.12      None
# 76515        18.95   2.75      0.0        0.00          0.00      None
# 76516        48.87   2.75      0.0        0.00          6.12      None
# 76517        15.45   2.75      0.0        0.00          0.00      None
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         65.40           NaN        NaN
# 76514                    0.3         65.28           NaN        NaN
# 76515                    0.3         22.00           NaN        NaN
# 76516                    0.3         58.04           NaN        NaN
# 76517                    0.3         18.50           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %% [markdown]
# If problems running `pd.read_parquet` use: `!pip install pyarrow`

# %%
print('Features:') 
data.columns.to_list()
# Out:
# Features:
# ['VendorID',
#  'lpep_pickup_datetime',
#  'lpep_dropoff_datetime',
#  'store_and_fwd_flag',
#  'RatecodeID',
#  'PULocationID',
#  'DOLocationID',
#  'passenger_count',
#  'trip_distance',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'ehail_fee',
#  'improvement_surcharge',
#  'total_amount',
#  'payment_type',
#  'trip_type',
#  'congestion_surcharge']

# %% [markdown]
# Interesting Columns:
# - PickUpLocationId
# - DropOffLocationId
# - Trip Distance

# %%
# 1. Create Target Feature (Duration)
data['duration'] = data['lpep_dropoff_datetime'] - data['lpep_pickup_datetime']
data['duration'] = data['duration'].apply(lambda x: x.total_seconds() / 60)
data['duration']
# Out:
# 0         3.933333
# 1         8.750000
# 2         5.966667
# 3         7.083333
# 4         0.066667
#            ...
# 76513    38.000000
# 76514    38.000000
# 76515    11.000000
# 76516    27.000000
# 76517    10.000000
# Name: duration, Length: 76518, dtype: float64

# %%
# 2. Let's have a look at target distribution
plt.figure(figsize=(12,6))
sns.distplot(data['duration']);

# %%
# 3. We see extreamly big and shrt duration trips
data['duration'].describe()
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 25%          8.000000
# 50%         13.883333
# 75%         23.000000
# max       1439.600000
# Name: duration, dtype: float64

# %%
data['duration'].describe(percentiles=[0.95, 0.99])
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 50%         13.883333
# 95%         44.000000
# 99%         67.158167
# max       1439.600000
# Name: duration, dtype: float64

# %%
# 4. let's filter the data and leave trips that more than 1 min and less than 60
data = data[(data['duration'] >= 1) & (data['duration'] <= 60)]
data
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7             2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 7             1.0            75            75              6.0           0.45
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50  ...      0.5        0.00          0.00       None
# 1            10.00  ...      0.5        2.81          0.00       None
# 2             6.00  ...      0.5        1.00          0.00       None
# 3             8.00  ...      0.5        0.00          0.00       None
# 7             3.50  ...      0.5        0.96          0.00       None
# ...            ...  ...      ...         ...           ...        ...
# 76513        56.23  ...      0.0        0.00          6.12       None
# 76514        46.66  ...      0.0       12.20          6.12       None
# 76515        18.95  ...      0.0        0.00          0.00       None
# 76516        48.87  ...      0.0        0.00          6.12       None
# 76517        15.45  ...      0.0        0.00          0.00       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3          6.80           2.0        1.0
# 1                       0.3         16.86           1.0        1.0
# 2                       0.3          8.30           1.0        1.0
# 3                       0.3          9.30           2.0        1.0
# 7                       0.3          5.76           1.0        1.0
# ...                     ...           ...           ...        ...
# 76513                   0.3         65.40           NaN        NaN
# 76514                   0.3         65.28           NaN        NaN
# 76515                   0.3         22.00           NaN        NaN
# 76516                   0.3         58.04           NaN        NaN
# 76517                   0.3         18.50           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00   3.933333
# 1                      2.75   8.750000
# 2                      0.00   5.966667
# 3                      0.00   7.083333
# 7                      0.00   2.316667
# ...                     ...        ...
# 76513                   NaN  38.000000
# 76514                   NaN  38.000000
# 76515                   NaN  11.000000
# 76516                   NaN  27.000000
# 76517                   NaN  10.000000
#
# [73908 rows x 21 columns]

# %%
# 5. let's pick some base line features 
cat_columns = ['PULocationID', 'DOLocationID']
num_columns = ['trip_distance']

# %%
cat_dummies = pd.get_dummies(data=data[cat_columns], columns=cat_columns, prefix_sep='_is_')
df = pd.concat([data[num_columns], cat_dummies], axis='columns')
df.head()
# Out:
#    trip_distance  PULocationID_is_3  PULocationID_is_4  PULocationID_is_7  \
# 0           1.01                  0                  0                  0
# 1           2.53                  0                  0                  0
# 2           1.12                  0                  0                  0
# 3           1.99                  0                  0                  0
# 7           0.45                  0                  0                  0
#
#    PULocationID_is_8  PULocationID_is_9  PULocationID_is_10  \
# 0                  0                  0                   0
# 1                  0                  0                   0
# 2                  0                  0                   0
# 3                  0                  0                   0
# 7                  0                  0                   0
#
#    PULocationID_is_11  PULocationID_is_12  PULocationID_is_13  ...  \
# 0                   0                   0                   0  ...
# 1                   0                   0                   0  ...
# 2                   0                   0                   0  ...
# 3                   0                   0                   0  ...
# 7                   0                   0                   0  ...
#
#    DOLocationID_is_256  DOLocationID_is_257  DOLocationID_is_258  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 7                    0                    0                    0
#
#    DOLocationID_is_259  DOLocationID_is_260  DOLocationID_is_261  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 7                    0                    0                    0
#
#    DOLocationID_is_262  DOLocationID_is_263  DOLocationID_is_264  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 7                    0                    0                    0
#
#    DOLocationID_is_265
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 7                    0
#
# [5 rows x 507 columns]

# %%
# 6. Create X_train and y_train
X_train = df.copy()
y_train = data['duration']

print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
# Out:
# X_train Shape:  (73908, 507)
# y_train Shape:  (73908,)

# %%
# 7. Train a model (simle Lin_reg)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 8. Let's make a prediction on the same data
y_pred = model.predict(X_train)

# %%
# 9. Let's have a look at distriburion (y_pred, y_train)
plt.figure(figsize=(12,6))
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')
plt.legend();

# %% [markdown]
# Comparision gives a sense that the score will be bad. We badly predict the target distribution

# %%
print('RMSE: ', mean_squared_error(y_train, y_pred, squared=False))
# Out:
# RMSE:  9.775258694561622

# %% [markdown]
# On average the model is wrong by 9 minutes (it's bad and this is the quality on Train Data)
#
# Let it be the baseline
#
# ### Baseline Improving

# %%
# 1. Create a func for features obtaining 
def prepare_df(filename):
    data = pd.read_parquet(filename)
    
    # Target Creation
    data['duration'] = data['lpep_dropoff_datetime'] - data['lpep_pickup_datetime']
    data['duration'] = data['duration'].apply(lambda x: x.total_seconds() / 60)
    
    # Filtering
    data = data[(data['duration'] >= 1) & (data['duration'] <= 60)]
    return data

def transform_df(df, cat_columns, num_columns):
    cat_dummies = pd.get_dummies(data=df[cat_columns], columns=cat_columns, prefix_sep='_is_')
    data = pd.concat([df[num_columns], cat_dummies], axis='columns')
    data['duration'] = df['duration']
    return data

# %%
    # Feature Selection
    cat_columns = ['PULocationID', 'DOLocationID']
    num_columns = ['trip_distance']
    
    # Feature Processing 
    cat_dummies = pd.get_dummies(data=data[cat_columns], columns=cat_columns, prefix_sep='_is_')
    df = pd.concat([data[num_columns], cat_dummies], axis='columns')
    df['duration'] = data['duration']

# %%
df_train = prepare_df('../data/green_tripdata_2021-01.parquet')
df_val = prepare_df('../data/green_tripdata_2021-02.parquet')

print('Train Shape: ', df_train.shape)
print('Validation Shape: ', df_val.shape)
# Out:
# Train Shape:  (73908, 21)
# Validation Shape:  (61921, 21)

# %%
cat_columns = ['PULocationID', 'DOLocationID']
num_columns = ['trip_distance']

df_train = transform_df(df_train, cat_columns=cat_columns, num_columns=num_columns)
df_val = transform_df(df_val, cat_columns=cat_columns, num_columns=num_columns)

# %%
# Out:
#        trip_distance  PULocationID_is_3  PULocationID_is_4  PULocationID_is_5  \
# 0               3.66                  0                  0                  0
# 1               1.10                  0                  0                  0
# 2               4.93                  0                  0                  0
# 3               6.70                  0                  0                  0
# 4               1.89                  0                  0                  0
# ...              ...                ...                ...                ...
# 64567           2.63                  0                  0                  0
# 64568           1.87                  0                  0                  0
# 64569           2.40                  0                  0                  0
# 64570           1.11                  0                  0                  0
# 64571           1.40                  0                  0                  0
#
#        PULocationID_is_7  PULocationID_is_8  PULocationID_is_9  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 64567                  0                  0                  0
# 64568                  0                  0                  0
# 64569                  0                  0                  0
# 64570                  0                  0                  0
# 64571                  0                  0                  0
#
#        PULocationID_is_10  PULocationID_is_11  PULocationID_is_13  ...  \
# 0                       0                   0                   0  ...
# 1                       0                   0                   0  ...
# 2                       0                   0                   0  ...
# 3                       0                   0                   0  ...
# 4                       0                   0                   0  ...
# ...                   ...                 ...                 ...  ...
# 64567                   0                   0                   0  ...
# 64568                   0                   0                   0  ...
# 64569                   0                   0                   0  ...
# 64570                   0                   0                   0  ...
# 64571                   0                   0                   0  ...
#
#        DOLocationID_is_257  DOLocationID_is_258  DOLocationID_is_259  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 64567                    0                    0                    0
# 64568                    0                    0                    0
# 64569                    0                    0                    0
# 64570                    0                    0                    0
# 64571                    0                    0                    0
#
#        DOLocationID_is_260  DOLocationID_is_261  DOLocationID_is_262  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 64567                    0                    0                    0
# 64568                    0                    0                    0
# 64569                    0                    0                    0
# 64570                    0                    0                    0
# 64571                    0                    0                    0
#
#        DOLocationID_is_263  DOLocationID_is_264  DOLocationID_is_265  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 64567                    0                    0                    0
# 64568                    0                    0                    0
# 64569                    0                    0                    0
# 64570                    0                    0                    0
# 64571                    0                    0                    0
#
#         duration
# 0      17.916667
# 1       6.500000
# 2      15.250000
# 3      18.233333
# 4       8.966667
# ...          ...
# 64567  10.000000
# 64568   9.000000
# 64569  14.000000
# 64570   7.000000
# 64571   7.000000
#
# [61921 rows x 501 columns]
